# %% [markdown]
# <a href="https://colab.research.google.com/github/AlasWorld/EDA/blob/main/Untitled51.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/stud_perf_exam.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# first just explore the various facts about the race/ethnicity

plt.pie(df["race/ethnicity"].value_counts(),labels=["C","D","B","E","A"],autopct="%1.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x7f04f7544340>,
# ...
#  [Text(0.592324332246979, 0.9269044640242977, 'C'),
#   Text(-1.0461621742897658, 0.3399186742226879, 'D'),
#   Text(-0.49322154359063347, -0.9832255636109514, 'B'),
#   Text(0.5952333666001212, -0.9250390474384775, 'E'),
#   Text(1.057281962489778, -0.3035701760610943, 'A')],
#  [Text(0.3230859994074431, 0.5055842531041623, '31.90'),
#   Text(-0.5706339132489631, 0.18541018593964795, '26.20'),
#   Text(-0.2690299328676182, -0.5363048528787007, '19.00'),
#   Text(0.32467274541824787, -0.5045667531482604, '14.00'),
#   Text(0.5766992522671516, -0.1655837323969605, '8.90')])

# %%
# pd.crosstab()race/ethnicitytest preparation course
plt.plot(pd.crosstab(df["race/ethnicity"],df["test preparation course"]),linewidth=15 )
plt.plot(pd.crosstab(df["race/ethnicity"],df["gender"]),linewidth=5)

# a has males as a major number of students
# while d is having same number of males of females

# %%
pd.crosstab(df["race/ethnicity"],df["test preparation course"])
# Out:
# test preparation course  completed  none
# race/ethnicity
# group A                         31    58
# group B                         68   122
# group C                        117   202
# group D                         82   180
# group E                         60    80

# %%
plt.bar(df["race/ethnicity"],df["math score"],)
plt.bar(df["race/ethnicity"],df["reading score"],width =0.5)
plt.bar(df["race/ethnicity"],df["writing score"],width =0.3)
# it is only the group d and group e where avg marks comes out to be same and high
# C and B are having low score where reading score and writing score are exceeding over each other.
# Out:
# <BarContainer object of 1000 artists>

# %%
d=[]
sub=["male","female"]
for i in df["gender"].unique():
  s=[]
  p=df[df["gender"]==i]
  s.append(p["math score"].mean())
  s.append(p["reading score"].mean())
  s.append(p["writing score"].mean())
  d.append(s)
plt.plot(sub,d)
# orange=reading score
# green =writing score
# blue= math score

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
prod=LogisticRegression()

from sklearn.metrics import accuracy_score

x=df.iloc[:,-3:]
for i in range (0,5):
  y=df.iloc[:,i]
  xtr,xts,ytr,yts = train_test_split(x,y, random_state=0)
  prod.fit(xtr,ytr)
  
  g=prod.predict(xts)
  print(accuracy_score(g,yts))
# Out:
# 0.896
# 0.332
# 0.24
# 0.688
# 0.652
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
y=df.iloc[:,0]
x=df.iloc[:,-3:]
xtr,xts,ytr,yts = train_test_split(x,y,random_state=0)
prod.fit(xtr,ytr)
  
g=prod.predict(xts)
print(accuracy_score(g,yts))
 
prod.coef_
# so the  maths marks are  correlated here with positive values, reading marks, writing marks  are the values
# which are negatively correlated.
# Out:
# 0.896
# array([[ 0.35013927, -0.06301491, -0.31974597]])

# %%
plt.scatter(df["math score"],df["reading score"]) 
plt.xlabel("math score")
plt.ylabel("reading score")
max(df["math score"]-df["reading score"])
# Out:
# 22

# %%
plt.scatter(df["math score"],df["writing score"]) 
plt.xlabel("math score")
plt.ylabel("writing score")
max(df["math score"]-df["writing score"])
# Out:
# 23

# %%
plt.scatter(df["math score"],df["reading score"]) 
plt.xlabel("writing score")
plt.ylabel("reading score")
max(df["writing score"]-df["reading score"])
# Out:
# 14

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# plt.bar(pd.crosstab(df["gender"],df["test preparation course"]["none"])
plt.bar(["female","male"],pd.crosstab(df["gender"],df["test preparation course"])["none"].values,width=.3)
plt.bar(["female","male"],pd.crosstab(df["gender"],df["test preparation course"])["completed"].values,width=.2)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.figure(figsize=(12,5))
plt.bar(["associate's degree","bachelor's degree","high school","master's degree","some college","some high school"],pd.crosstab(df["parental level of education"],df["test preparation course"])["completed"])
plt.bar(["associate's degree","bachelor's degree","high school","master's degree","some college","some high school"],pd.crosstab(df["parental level of education"],df["test preparation course"])["none"],width=0.6)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.scatter(df[ "math score"],df["parental level of education"])
plt.scatter(df[ "reading score"],df["parental level of education"],marker="D")
plt.scatter(df[ "writing score"],df["parental level of education"],marker="H")

# %%
d=[]
h=df["lunch"].unique()
for i in df["lunch"].unique():
  s=[]
  p=df[df["lunch"]==i]
  s.append(p["math score"].mean())
  s.append(p["reading score"].mean())
  s.append(p["writing score"].mean())
  d.append(s)
jh=["math score","reading score","writing score"]
kl=pd.DataFrame(d)
plt.figure(figsize=(10,5))
for i in range(0,3):
  plt.subplot(1,3,i+1)
  plt.title(jh[i])
  plt.pie(kl[i],labels=h,autopct="%1.2f")

# %%
s=[]
for i in df.iloc[:,-3:].values:
  s.append(sum(i))
df["sum"]=pd.DataFrame(s)

# %%
plt.plot(df["sum"])

# %%
t=[]
t.append(df["math score"].mean())

t.append(df["reading score"].mean())
t.append(df["writing score"].mean())
t
plt.pie(t,labels=["math score","reading score","writing score"],autopct="%1.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x7f04f1f81730>,
# ...
#  [Text(0.5745657945314301, 0.9380160700939332, 'math score'),
#   Text(-1.0994929759738084, 0.03339454722344115, 'reading score'),
#   Text(0.545824030339108, -0.9550267681611718, 'writing score')],
#  [Text(0.3133995242898709, 0.5116451291421453, '32.51'),
#   Text(-0.599723441440259, 0.01821520757642244, '34.02'),
#   Text(0.29772219836678615, -0.5209236917242756, '33.47')])

# %%
plt.subplot(1,2,1)
plt.pie(pd.crosstab(df.gender,df.lunch)["free/reduced"],labels=["female","male"],autopct="%1.2f")
plt.subplot(1,2,2)
plt.pie(pd.crosstab(df.gender,df.lunch)["standard"],labels=["female","male"],autopct="%1.2f")


 

pd.crosstab(df.gender,df.lunch)
# Out:
# lunch   free/reduced  standard
# gender
# female           189       329
# male             166       316
