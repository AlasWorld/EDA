# %% [markdown]
# <a href="https://colab.research.google.com/github/AlasWorld/EDA/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/ODI data.csv")
g=df       #  to make copies of data to analyze it properly 
h=df
df
# Out:
#       Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
# ...          ...                          ...        ...  ...  ...  ..    ...
# 2495          45              ZS Ansari (ENG)  2015-2015    1    -   -      -
# 2496          46         Ariful Haque (BDESH)  2018-2018    1    -   -      -
# 2497          47           Ashfaq Ahmed (PAK)  1994-1994    3    -   -      -
# 2498          48               MD Bailey (NZ)  1998-1998    1    -   -      -
# 2499          49               GR Beard (AUS)  1981-1981    2    -   -      -
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2500 non-null   int64
#  1   Player       2500 non-null   object
#  2   Span         2500 non-null   object
#  3   Mat          2500 non-null   int64
#  4   Inns         2500 non-null   object
#  5   NO           2500 non-null   object
#  6   Runs         2500 non-null   object
#  7   HS           2500 non-null   object
#  8   Ave          2500 non-null   object
#  9   BF           2500 non-null   object
#  10  SR           2500 non-null   object
#  11  100          2500 non-null   object
#  12  50           2500 non-null   object
#  13  0            2500 non-null   object
#  14  Unnamed: 13  0 non-null      float64
# dtypes: float64(1), int64(2), object(12)
# memory usage: 293.1+ KB

# %%
df.Mat.astype(str).astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2500 non-null   int64
#  1   Player       2500 non-null   object
#  2   Span         2500 non-null   object
#  3   Mat          2500 non-null   int64
#  4   Inns         2500 non-null   object
#  5   NO           2500 non-null   object
#  6   Runs         2500 non-null   object
#  7   HS           2500 non-null   object
#  8   Ave          2500 non-null   object
#  9   BF           2500 non-null   object
#  10  SR           2500 non-null   object
#  11  100          2500 non-null   object
#  12  50           2500 non-null   object
#  13  0            2500 non-null   object
#  14  Unnamed: 13  0 non-null      float64
# dtypes: float64(1), int64(2), object(12)
# memory usage: 293.1+ KB

# %%
# Find the batsman with highest strike rate and the country forwhich he played and how many rns did he score?



df.SR=df.SR.str.replace("-","0")
df.SR.astype(str).astype(float)
df[df.SR==max(df.SR)]
  
  
# Rashid Khan from Afghanistan had scored 905 runs in his career while playing for Afghanistan.
# Out:
#      Unnamed: 0             Player       Span  Mat Inns NO Runs   HS    Ave  \
# 417          17  Rashid Khan (AFG)  2015-2019   71   56  9  905  60*  19.25
#
#       BF     SR 100 50  0  Unnamed: 13
# 417  906  99.88   0  4  6          NaN

# %%
# Find those players who had  been  not out when he knocked their best innings ?
h[h["HS"].str.find("*")!=-1]
# Out:
#       Unnamed: 0                      Player       Span  Mat Inns  NO   Runs  \
# 0              0        SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 5              5   Inzamam-ul-Haq (Asia/PAK)  1991-2007  378  350  53  11739
# 10            10       MS Dhoni (Asia/INDIA)  2004-2019  350  297  84  10773
# 13            13             TM Dilshan (SL)  1999-2016  330  303  41  10290
# 14            14  Mohammad Yousuf (Asia/PAK)  1998-2010  288  273  40   9720
# ...          ...                         ...        ...  ...  ...  ..    ...
# 2471          21            NV Radford (ENG)  1988-1988    6    3   2      0
# 2473          23            CAK Rajitha (SL)  2018-2019    9    3   2      0
# 2478          28        Robiul Islam (BDESH)  2013-2013    3    1   1      0
# 2482          32               T Shamsi (SA)  2016-2019   17    3   2      0
# 2486          36     M Venkataramana (INDIA)  1988-1988    1    1   1      0
#
# ...

# %%
# Which player did serve his with the longest career?

p=df.Span.str[0:4].astype(str).astype(int)
q=df.Span.str[5:].astype(str).astype(int)
print(df[q-p==max(q-p)],max(q-p))
# Sachin Tendulkar From India had played for 23 years from India from his debut in 1989 till his retirement in 2012.
# Out:
#    Unnamed: 0                Player       Span  Mat Inns  NO   Runs    HS  \
# 0           0  SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*
#
#      Ave     BF     SR 100  50   0  Unnamed: 13
# 0  44.83  21367  86.23  49  96  20          NaN   23

# %%
# Since  all the numeric data is given as objects we are in need to typecast it into float for further analysis. 


p=df.iloc[:,4:14]
for feature in p:
  df[feature]=df[feature].str.replace("-","0")
for feature in p:
  df[feature]=df[feature].str.replace("*","")
for feature in p:
   df[feature]=df[feature].astype(str).astype(float)
# Out:
# <ipython-input-8-71a4f1f15a56>:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[feature]=df[feature].str.replace("*","")

# %%
p=g.iloc[:,4:14]
for feature in p:
  g[feature]=g[feature].str.replace("-","0")
for feature in p:
  g[feature]=g[feature].str.replace("*","")
for feature in p:
   g[feature]=g[feature].astype(str).astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-9b85d8f67e64> in <module>
#       1 p=g.iloc[:,4:14]
#       2 for feature in p:
# ----> 3   g[feature]=g[feature].str.replace("-","0")
#       4 for feature in p:
#       5   g[feature]=g[feature].str.replace("*","")
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2500 non-null   int64
#  1   Player       2500 non-null   object
#  2   Span         2500 non-null   object
#  3   Mat          2500 non-null   int64
#  4   Inns         2500 non-null   float64
#  5   NO           2500 non-null   float64
#  6   Runs         2500 non-null   float64
#  7   HS           2500 non-null   float64
#  8   Ave          2500 non-null   float64
#  9   BF           2500 non-null   float64
#  10  SR           2500 non-null   float64
#  11  100          2500 non-null   float64
#  12  50           2500 non-null   float64
#  13  0            2500 non-null   float64
#  14  Unnamed: 13  0 non-null      float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 293.1+ KB

# %%
# who dod scored the highest number of centuries and had not made his debut in 21st century , had also ever scored above 200?
p=g[g.HS>200]
v=p[p.Span.str[0:4].astype(str).astype(int)<2000]
v[v["100"]==max(v["100"])]
# The debutant of the 20th century who had scored the most number of centuries and also had ever exceeded the double century mark is CH Gayle.
# Out:
#     Unnamed: 0             Player       Span  Mat   Inns    NO     Runs  \
# 11          11  CH Gayle (ICC/WI)  1999-2019  301  294.0  17.0  10480.0
#
#        HS    Ave       BF     SR   100    50     0  Unnamed: 13
# 11  215.0  37.83  12019.0  87.19  25.0  54.0  25.0          NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(df.HS)
# The highest score of these players is decreasing with index so the players had been prioritised on their high Score as well.
# Techinically , a  most of the players had scored their best which is lying in the range of 50-150.
# However , a significant portion also is lying and below 50 and similarly very few exceptionally had also scored above 200.
# Out:
# <Axes: ylabel='HS'>

# %%
plt.scatter(df.Mat,df.HS)
# Clearly the plot is going in the favour of the fact that there is  a increasing trend of the highest score with more number of matches.
# It is not even wrong to say that most players had retired before they could have play their 150th match .

# %%
# lets estimate the no of bowlers in the dataset

# For which we will first look for those players whose no of innings played by them is critically low with respect to their Matches.
g[g["Inns"]/g["Mat"]<0.3]
# Out:
#       Unnamed: 0                Player       Span  Mat  Inns    NO   Runs  \
# 951            1      M Ntini (ICC/SA)  1998-2009  173  47.0  24.0  199.0
# 1142          42            A Nel (SA)  2001-2008   79  22.0  12.0  127.0
# 1187          37  GD McGrath (AUS/ICC)  1993-2007  250  68.0  38.0  115.0
# 1212          12   MJ McClenaghan (NZ)  2013-2016   48  14.0  10.0  108.0
# 1276          26        AA Donald (SA)  1991-2003  164  40.0  18.0   95.0
# ...          ...                   ...        ...  ...   ...   ...    ...
# 2495          45       ZS Ansari (ENG)  2015-2015    1   0.0   0.0    0.0
# 2496          46  Ariful Haque (BDESH)  2018-2018    1   0.0   0.0    0.0
# 2497          47    Ashfaq Ahmed (PAK)  1994-1994    3   0.0   0.0    0.0
# 2498          48        MD Bailey (NZ)  1998-1998    1   0.0   0.0    0.0
# 2499          49        GR Beard (AUS)  1981-1981    2   0.0   0.0    0.0
#
#         HS    Ave     BF     SR  100   50     0  Unnamed: 13
# ...

# %%
sns.scatterplot(df.Runs)
# Out:
# <Axes: ylabel='Runs'>

# %%
df[df["100"]==max(df["100"])]
# Out:
#    Unnamed: 0                Player       Span  Mat   Inns    NO     Runs  \
# 0           0  SR Tendulkar (INDIA)  1989-2012  463  452.0  41.0  18426.0
#
#       HS    Ave       BF     SR   100    50     0  Unnamed: 13
# 0  200.0  44.83  21367.0  86.23  49.0  96.0  20.0          NaN

# %%
plt.plot(df.Mat,df.Runs)
plt.xlabel("Matches")
plt.ylabel("Runs")
plt.title("Matches vs Runs")
# Out:
# Text(0.5, 1.0, 'Matches vs Runs')

# %%
df_ind=df[df.Player.str.find("INDIA")!=-1]

# %%
df_ind[df.NO==max(df.NO)]
# the player who had been not out for most nuber of times in india.
# Out:
# <ipython-input-21-df70f0ab1f61>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_ind[df.NO==max(df.NO)]
#     Unnamed: 0                 Player       Span  Mat   Inns    NO     Runs  \
# 10          10  MS Dhoni (Asia/INDIA)  2004-2019  350  297.0  84.0  10773.0
#
#        HS    Ave       BF     SR   100    50     0  Unnamed: 13
# 10  183.0  50.57  12303.0  87.56  10.0  73.0  10.0          NaN

# %%
df_ind
# Out:
#       Unnamed: 0                     Player       Span  Mat   Inns    NO  \
# 0              0       SR Tendulkar (INDIA)  1989-2012  463  452.0  41.0
# 6              6            V Kohli (INDIA)  2008-2019  242  233.0  39.0
# 8              8    SC Ganguly (Asia/INDIA)  1992-2007  311  300.0  23.0
# 9              9  R Dravid (Asia/ICC/INDIA)  1996-2011  344  318.0  40.0
# 10            10      MS Dhoni (Asia/INDIA)  2004-2019  350  297.0  84.0
# ...          ...                        ...        ...  ...    ...   ...
# 2422          22           NS Yadav (INDIA)  1986-1987    7    2.0   2.0
# 2423          23     B Yograj Singh (INDIA)  1980-1981    6    4.0   2.0
# 2431          31         A Bhandari (INDIA)  2000-2004    2    1.0   1.0
# 2463          13           AM Nayar (INDIA)  2009-2009    3    1.0   1.0
# 2486          36    M Venkataramana (INDIA)  1988-1988    1    1.0   1.0
#
#          Runs     HS    Ave       BF     SR   100    50     0  Unnamed: 13
# ...

# %%
print(df_ind.describe(),"India")
df_Aus=df[df.Player.str.find("AUS")!=-1]
print(df_Aus.describe(),"Austalia")


# The following points can be highlighted:

# All the Indians had atleast a inning in their whole career and there is no one who didn't come to bat for India.
# The average matches played by Australia and India are comparitively low and India.
# The Indian Players had scored more centuries than the Australians.
# Both the teams have the similiar mean strike rates.
# Both the Runs scored  and Inns played , by the players were  higher for Indians.
# Out:
#        Unnamed: 0         Mat        Inns          NO          Runs  \
# count  217.000000  217.000000  217.000000  217.000000    217.000000
# mean    23.930876   49.829493   37.419355    7.506912    943.391705
# std     14.069267   77.025570   67.307986   11.873219   2394.653669
# min      0.000000    1.000000    1.000000    0.000000      0.000000
# 25%     12.000000    4.000000    3.000000    1.000000     19.000000
# 50%     23.000000   16.000000   11.000000    2.000000    100.000000
# 75%     35.000000   57.000000   34.000000    9.000000    526.000000
# max     49.000000  463.000000  452.000000   84.000000  18426.000000
#
#                HS         Ave            BF          SR         100  \
# count  217.000000  217.000000    217.000000  217.000000  217.000000
# mean    49.525346   16.978341   1205.073733   66.879263    1.345622
# std     48.790278   13.209617   2910.175191   24.888800    5.475991
# min      0.000000    0.000000      0.000000    0.000000    0.000000
# ...

# %%
p=df_ind[df_ind.Span.str[5:].astype(str).astype(int)<2006 ]
q=p[p.Span.str[0:4].astype(str).astype(int)>2000]
q[q.SR==max(q.SR)]

#The player with maximum strike rate in India who had his career between in 2000-2006
# Out:
#      Unnamed: 0             Player       Span  Mat  Inns   NO   Runs    HS  \
# 987          37  SB Bangar (INDIA)  2002-2004   15  15.0  2.0  180.0  57.0
#
#        Ave     BF     SR  100   50    0  Unnamed: 13
# 987  13.84  239.0  75.31  0.0  1.0  3.0          NaN

# %%
df_Aus=df[df.Player.str.find("AUS")!=-1]
df_Aus
df_Aus.describe()
# Out:
#        Unnamed: 0         Mat        Inns          NO          Runs  \
# count  219.000000  219.000000  219.000000  219.000000    219.000000
# mean    24.671233   47.972603   36.333333    7.347032    928.497717
# std     15.221956   65.696963   57.131294   10.989909   1935.624427
# min      0.000000    1.000000    0.000000    0.000000      0.000000
# 25%     11.000000    5.000000    3.000000    1.000000     30.000000
# 50%     25.000000   22.000000   13.000000    3.000000    125.000000
# 75%     37.500000   64.000000   41.500000    9.000000    824.500000
# max     49.000000  375.000000  365.000000   67.000000  13704.000000
#
#                HS         Ave            BF          SR         100  \
# count  219.000000  219.000000    219.000000  219.000000  219.000000
# mean    54.132420   19.835890   1197.657534   68.816164    1.041096
# std     48.549283   14.269866   2460.921772   26.071966    3.370562
# min      0.000000    0.000000      0.000000    0.000000    0.000000
# ...

# %%
print(min(df.Span.str[0:4].astype(str).astype(int)))
max(((df.Span.str[5:].astype(str).astype(int))))
# Out:
# 1971
# 2019
