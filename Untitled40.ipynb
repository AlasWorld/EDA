# %% [markdown]
# <a href="https://colab.research.google.com/github/AlasWorld/EDA/blob/main/Untitled40.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/Wine_Quality_Data (1).csv")
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         6497 non-null   float64
#  1   volatile_acidity      6497 non-null   float64
#  2   citric_acid           6497 non-null   float64
#  3   residual_sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free_sulfur_dioxide   6497 non-null   float64
#  6   total_sulfur_dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  color                 6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.pH.mean()
# Out:
# 3.2185008465445586

# %%
df.color.value_counts()
plt.pie(df.color.value_counts(),labels=["white","red"])
# The white wine is in majority  in our dataset in comparison to red wine.
# Out:
# ([<matplotlib.patches.Wedge at 0x7f141464d190>,
# ...
#  [Text(-0.7872560039826877, 0.7682629655223598, 'white'),
#   Text(0.7872559680177021, -0.7682630023764719, 'red')])

# %%
sns.scatterplot(x=df.citric_acid,y=df.pH,hue=df.color ,palette=["red","Blue"])
# As expected the ph is in decline,with increasing amount of citric acid , however for the standardization of wine
# it can be said that ph lies between 2.6-4 ph  with the percentage of citric acid below than 0.75 in general.
# Out:
# <Axes: xlabel='citric_acid', ylabel='pH'>

# %%
sns.scatterplot(x=df.citric_acid,y=df.pH,hue=df.quality,palette=["red","Blue","orange","magenta","black","brown","Green"])
#The quality of wine is independent of the ph range and citric acid, there is no such a clear demarcation for
#its dependency as all the quality standards of wine varies uniformly along the both ph of wine as well as the 
#the content of citric_acid .
# Out:
# <Axes: xlabel='citric_acid', ylabel='pH'>

# %%
sns.scatterplot(x=df.volatile_acidity,y=df.pH,hue=df.quality,palette=["red","Blue","orange","magenta","black","brown","Green"])
# Even by its name ,it is being suggested as well supported by the plot , that volatile acidity has nothing much to
# do with the ph as there is no such a profound  effect on acidity im real terms of ph and ph is still hitting its 
# minima even  with the lowest amount of volatile_acidity.
# Out:
# <Axes: xlabel='volatile_acidity', ylabel='pH'>

# %%
sns.scatterplot(x=df.volatile_acidity ,y=df.pH,hue=df.color,palette=["black","green"])
# There is a clear cut demarcation which leads us to the fact that the red is having higher volatile acidity and 
# the white is hitting  the lowest ph instead of red wine strenthening the above said fact .
# Out:
# <Axes: xlabel='volatile_acidity', ylabel='pH'>

# %%
sns.scatterplot(x=df.residual_sugar   ,y=df.density ,hue=df.color,palette=["black","green"])
df[df.residual_sugar==max(df.residual_sugar)]
# There is a exceptional outliner in the data with having the thrice of the usual amount of the sugar 
#,no doubt, it is corresponding to the sharp rise in the density .Probably it is the case of some error .
# Usually the red wine is having the lower amount of sugar still with higher density than the that of white ones 
# within the same range of the amount of sugar.
# The linear realationship of density with residual amount of sugar is better fit with white wines.
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 4380            7.8             0.965          0.6            65.8      0.074
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 4380                  8.0                 160.0  1.03898  3.39       0.69
#
#       alcohol  quality  color
# 4380     11.7        6  white

# %%
print(df.groupby(["quality"]).size())
print(plt.scatter(df.quality,df.density ))
# The qulality standard of wine with 6,7and 5 indices is in huge demand and must be of coarse  quality product 
# meant for targeting the pockets of mass consumers but rest 3,4 and 8 rated wines are produced in 
# lower amounts may be due to different reasons.
# Out:
# quality
# 3      30
# 4     216
# 5    2138
# 6    2836
# 7    1079
# 8     193
# 9       5
# dtype: int64
# ...

# %%
# print( sns.scatterplot(x=df.total_sulfur_dioxide,y=df.free_sulfur_dioxide,hue=df.color,palette=["black","green"]))


x=df.total_sulfur_dioxide
y=df.free_sulfur_dioxide
y/x

(sns.scatterplot(x=df.quality,y=y/x))
# Still showing that the coarse quality wines (6,7,8 rated) are having the largest variation in the % of 
# free sulfur dioxide in these  vines  ,this may be possibile due to meet customers' taste.
# Out:
# <Axes: xlabel='quality'>

# %%
sns.scatterplot(x=df.total_sulfur_dioxide,y=df.free_sulfur_dioxide,hue=df.quality,palette=["red","Blue","orange","magenta","black","brown"]) 
# clearly to save cost, the high selling wines are saturated with higher amount of sulphur dioxide.
# Out:
# <ipython-input-14-9cd34610e415>:1: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x=df.total_sulfur_dioxide,y=df.free_sulfur_dioxide,hue=df.quality,palette=["red","Blue","orange","magenta","black","brown"])
# <Axes: xlabel='total_sulfur_dioxide', ylabel='free_sulfur_dioxide'>

# %%
from sklearn.linear_model import LogisticRegression
mod=LogisticRegression()
x=df.iloc[:,0:11].values
y=df.iloc[:,12].values
from sklearn.preprocessing import MinMaxScaler
r=MinMaxScaler()
x=r.fit_transform(x)

from sklearn.model_selection import train_test_split
xtr,xts,ytr,yts=train_test_split(x,y,random_state=1)
mod.fit(xtr,ytr)
h=mod.predict(xts)
from sklearn.metrics import accuracy_score
accuracy_score(h,yts)


#This model can be used for predicting the color of the wine with 98% accuracy
# Out:
# 0.9846153846153847

# %%
sns.barplot(x=df.alcohol,y=df.color,palette=["black","pink","orange","green","purple","red","yellow"],hue=df.quality)
# there is not a single red wine with index 9.
# Again the wines which are being sold the most , are having the comparitively higher amount of alcohols.
# The quality indexed 5 is the wine with the least amount of alcohol.
# Since the Index 9 wine is produced in very low quantity and still, in contrast, is found to have the 
# highest amount of alcohols but exist just nominally  claiming that it may be the most rare and expensive wine prepared
# for either any special purpose or on experimental basis.
# Out:
# <Axes: xlabel='alcohol', ylabel='color'>

# %%
sns.barplot(x=df.residual_sugar,y=df.color, palette=["black","pink","orange","green","purple","red","yellow"],hue=df.quality)
# It is the white wine having the higher amount of sugar and and specifically the quality index 5,  in comparison to the red wines
# Out:
# <Axes: xlabel='residual_sugar', ylabel='color'>

# %%
sns.scatterplot(x=df.residual_sugar,y=df.alcohol,hue=df.quality,palette=["black","pink","orange","green","purple","red","yellow"])
# the plot is showing this these wines are having the tendency to have either the higher amount of alcohol in combination with 
# low sugar or conversly the high sugar combined with low alcohol.
# Out:
# <Axes: xlabel='residual_sugar', ylabel='alcohol'>

# %%
p=df[df.color=="red"]
plt.title("Red-Quality Distribution")
plt.pie(p.quality.value_counts(),labels=p.quality.unique(),explode=[0.1,0.1,0.1,0.1,0.11,0.11],colors=["black","pink","orange","green","purple","red","yellow"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f140eee0a30>,
# ...
#  [Text(0.27686646197324155, 1.1676236389498202, '5'),
#   Text(-0.8464416603825814, -0.8506094965192775, '6'),
#   Text(0.9106088097306917, -0.7815315704697112, '7'),
#   Text(1.1725876251729683, -0.2550260012061875, '4'),
#   Text(1.2066292710778073, -0.09025409784735289, '8'),
#   Text(1.2097664688105738, -0.023771641541878444, '3')])

# %%
d=df[df.color=="white"]
plt.title("White-Quality Distribution")
plt.pie(d.quality.value_counts(),labels=d.quality.unique(),explode=[0.1,0.1,0.1,0.1,0.11,0.11,0.1],colors=["black","pink","orange","green","purple","red","yellow"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f140ef42910>,
# ...
#  [Text(0.19235723174898106, 1.184482458879771, '6'),
#   Text(-0.981828384668321, -0.6899369703527968, '5'),
#   Text(0.6176864030476142, -1.0288165567729266, '7'),
#   Text(1.1258362322216866, -0.41532249904968643, '8'),
#   Text(1.1987253871974721, -0.16479516403180916, '4'),
#   Text(1.2097759989845749, -0.023281586734467744, '3'),
#   Text(1.1999938287487386, -0.0038485016491324126, '9')])

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
from sklearn.linear_model import LinearRegression
mod=LinearRegression()
df
x=df.drop(["density","quality","color","pH"],axis=1).iloc[:].values
x
y=df.iloc[:,7].values
# from sklearn.model_selection import train_test_split
# xtr,xts,ytr,yts=train_test_split(x,y,random_state=0)
# mod.fit(xtr,ytr)
# y=mod.predict(xts)
mod.fit(x,y)
h=mod.predict(x)
plt.plot(h)
plt.plot(df.iloc[:,7])
# This plot is showing that how accurate is our model .
mod.coef_
j=df.drop(["density","quality","color","pH"],axis=1).columns

# %%
mod.coef_
j=df.drop(["density","quality","color","pH"],axis=1).columns

sns.barplot(x=mod.coef_,y=j)


# clearly the density of alcohol must be lower than the wine and it adds to the taste since it was already
# high in the highest selling wines.
# surprisingly the density of the citric acid and residual_sugar is higher than the wines but still here in this 
# model, is not having the much influence on density.
# Out:
# <Axes: >

# %%
y1=df.iloc[:,8].values
x1=df.iloc[:,0:2].values
x1
mod.fit(x,y1)
pH_pred=mod.predict(x)
plt.plot(df.pH)
plt.plot(pH_pred)
# this plot signifying that pH couldn't be predicted with much accuracy so we have to deal with only those facts derived from the earlier graphs
# considering the acidity of the wine.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         6497 non-null   float64
#  1   volatile_acidity      6497 non-null   float64
#  2   citric_acid           6497 non-null   float64
#  3   residual_sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free_sulfur_dioxide   6497 non-null   float64
#  6   total_sulfur_dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  color                 6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
from sklearn.linear_model import LogisticRegression
prod=LogisticRegression()
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
xt=scaler.fit_transform(x)
y=df.iloc[:,11].values.reshape(-1,1)

from sklearn.model_selection import train_test_split
xtr,xts,ytr,yts=train_test_split(xt,y,random_state=0)
prod.fit(xtr,ytr)
p=prod.predict(xts)
from sklearn.metrics import accuracy_score
accuracy_score(p,yts)*100
# This level of accuracy also ensure you that such level of accuracy will never be going to be used for predicting the 
# the quality standards of wines.
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 51.815384615384616

# %%
y2=df.iloc[:,12]
xtr2,xts2,ytr2,yts2=train_test_split(xt,y2,random_state=0)
prod.fit(xtr2,ytr2)
a=prod.predict(xts2)
from sklearn.metrics import accuracy_score
accuracy_score(a,yts2)*100

ki=[]
for i in range(0,9):
  ki.append(prod.coef_[0][i])

sns.barplot(x=ki,y=j)
# significantly , the citric acid,the residual_sugar,and the amount of total and free sulfur dioxide and the alcohol which majorly, 
# influence the color of the wine
# Out:
# <Axes: >
